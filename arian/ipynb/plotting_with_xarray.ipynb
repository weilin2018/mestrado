# %% [markdown]
# ### Plotando NetCDF com Xarray
#
# Se não tem instalado, acesse seu ambiente virtual e digite:
#
#     conda install xarray

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# /home/danilo/miniconda2/envs/mestrado/lib/python2.7/site-packages/xarray/conventions.py:9: FutureWarning: The pandas.tslib module is deprecated and will be removed in a future version.
#   from pandas.tslib import OutOfBoundsDatetime

# %%
# import netcdf file
ncin = xr.open_dataset('/home/danilo/mestrado/arian/pcse_only.nc',decode_times=False)

# extract only temperature
temp = ncin.TEMP[0,:,:,:]

# printing dimensions to better understanding
print(temp.coords.dims)
# Out:
# (u'DEPTH', u'LATITUDE', u'LONGITUDE')

# %%
# plotting SST -> select only depth = 0
temp.isel(DEPTH=0).plot()

# %%
# plotting near bottom tempertura
temp.isel(DEPTH=3).plot()

# %% [markdown]
# #### Vertical Sections / Transect
